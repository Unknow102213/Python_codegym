# %%
'''
Khởi động 1: Viết chương trình in ra tất cả các số chia hết cho cả 5 và 7 trong khoảng từ 1500 đến 2700
'''

# %% [markdown]
# ![%E1%BA%A2nh%20ch%E1%BB%A5p%20m%C3%A0n%20h%C3%ACnh%202023-06-01%20130515.png](attachment:%E1%BA%A2nh%20ch%E1%BB%A5p%20m%C3%A0n%20h%C3%ACnh%202023-06-01%20130515.png)

# %%
i=1500
while i <= 2700:
    if i % 5 == 0 and i % 7 == 0 :
        print(i)
    i+=1
# Out:
# 1505
# 1540
# 1575
# 1610
# 1645
# 1680
# 1715
# 1750
# 1785
# 1820
# 1855
# 1890
# 1925
# 1960
# 1995
# 2030
# 2065
# 2100
# 2135
# 2170
# 2205
# 2240
# 2275
# 2310
# 2345
# 2380
# 2415
# 2450
# 2485
# 2520
# 2555
# 2590
# 2625
# 2660
# 2695

# %%
'''
Bài 1: Viết chương trình nhập vào chiều cao tam giác vuông và in ra tam giác có hình dạng như sau:
*****
****
***
** 
*
'''
hight=int(input("nhập chiều cao của tam giác: "))
while hight >= 1:
    print('*'*hight)
    hight-=1
# Out:
# nhập chiều cao của tam giác: 5
# *****
# ****
# ***
# **
# *

# %% [markdown]
# ![%E1%BA%A2nh%20ch%E1%BB%A5p%20m%C3%A0n%20h%C3%ACnh%202023-06-01%20132546.png](attachment:%E1%BA%A2nh%20ch%E1%BB%A5p%20m%C3%A0n%20h%C3%ACnh%202023-06-01%20132546.png)

# %%
'''
Bài 2: Viết chương trình nhập vào chiều cao tam giác vuông và in ra tam giác có hình dạng như sau:
* * * * * *
* * * * *
* * * *
* * *
* *
*
'''
hight=int(input("nhập chiều cao của tam giác: "))
star='* '
while hight >= 1:
    out=star*hight
    print(out)
    hight-=1
# Out:
# nhập chiều cao của tam giác: 6
# * * * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %% [markdown]
# ![%E1%BA%A2nh%20ch%E1%BB%A5p%20m%C3%A0n%20h%C3%ACnh%202023-06-01%20133010.png](attachment:%E1%BA%A2nh%20ch%E1%BB%A5p%20m%C3%A0n%20h%C3%ACnh%202023-06-01%20133010.png)

# %%
'''
Bài 3: Viết chương trình nhập vào chiều cao tam giác vuông và in ra tam giác có hình dạng như sau:
* - * - *
* - * -
* - *
* -
*
'''
hight=int(input("nhập chiều cao của tam giác: "))
star='*-'
while hight >= 1:
    out=star*hight
    print(out)
    hight-=1
# Out:
# nhập chiều cao của tam giác: 5
# *-*-*-*-*-
# *-*-*-*-
# *-*-*-
# *-*-
# *-

# %%
'''
Bài 4: Viết chương trình nhập vào một số nguyên n và in ra các số từ 1 đến n với các trường hợp ngoại lệ như sau:
- Nếu số đó chia hết cho 3 thì in "py"
- Nếu số đó chia hết cho 7 thì in "thon"
- Nếu số đó chia hết cho cả 3 và 4 thì in "python"

Ví dụ: n = 25
1
2
py
4
5
py
thon
8
py
10
11
py
13
thon
py
16
17
py
19
20
python
22
23
py
25
'''
n=int(input("nhập số n: "))
i=1
while i<n:
    if i % 3 == 0 and i % 4 == 0 :
        print("python")
        i+=1
    elif i % 3 == 0 :
        print("py")
        i+=1
    elif i % 7 == 0 :
        print("thon")
        i+=1
    else:
        print(i)
        i+=1
# Out:
# nhập số n: 10
# 1
# 2
# py
# 4
# 5
# py
# thon
# 8
# py

# %% [markdown]
# ![%E1%BA%A2nh%20ch%E1%BB%A5p%20m%C3%A0n%20h%C3%ACnh%202023-06-01%20134002.png](attachment:%E1%BA%A2nh%20ch%E1%BB%A5p%20m%C3%A0n%20h%C3%ACnh%202023-06-01%20134002.png)

# %%
 '''
Bài 5: Viết chương trình nhập vào một số và kiểm tra xem số đó có phải là số nguyên tố hay không
Note: Số nguyên tố là số chỉ chia hết cho 1 và chính nó
'''
n=int(input("nhập số tự nhiên: "))
test=1
i=1

if n<2:
    test=0

while i<=n:
    i=i+1
    if n % i == 0 :
        test=0
    break

if n==2:
    test=1

if test == 1:
    print(n,"là số nguyên tố")
else:
    print(n,"không phải số nguyên tố")
# Out:
# nhập số tự nhiên: 2
# 2 là số nguyên tố

# %% [markdown]
# ![%E1%BA%A2nh%20ch%E1%BB%A5p%20m%C3%A0n%20h%C3%ACnh%202023-06-01%20145648.png](attachment:%E1%BA%A2nh%20ch%E1%BB%A5p%20m%C3%A0n%20h%C3%ACnh%202023-06-01%20145648.png)

# %%
'''
Bài 6: Viết chương trình mô phỏng trò chơi kéo búa bao theo luật chơi như sau:
Quy ước: 1 - búa, 2 - kéo, 3 - bao
Khi trò chơi bắt đầu, yêu cầu người chơi nhập 1 số từ bàn phím đại diện cho kéo, búa, bao
Chương trình tự random ra một lựa chọn từ 1 đến 3.
Nếu người chơi thua thì tiếp tục chơi cho đến khi thắng thì kết thúc chương trình.
Ví dụ:

Mời lựa chọn(1 - búa, 2 - kéo, 3 - bao): 1
Máy tính chọn: 3
Người chơi thua.

Mời lựa chọn(1 - búa, 2 - kéo, 3 - bao): 2
Máy tính chọn: 1
Người chơi thua.

Mời lựa chọn(1 - búa, 2 - kéo, 3 - bao): 1
Máy tính chọn: 2
Người chơi thắng.
'''
from random import randint

player = int(input("Mời lựa chọn(1 - búa, 2 - kéo, 3 - bao): "))
computer = randint(1,3)
 
if computer == 1:
    computer = "Búa"
if computer == 2:
    computer = "Kéo"
if computer == 3:
    computer = "Bao"

if player==1:
    player = "Búa"
    print("Ban chọn: Búa")
elif player==2:
    player = "Kéo"
    print("bạn chọn Kéo")
elif player==3:
    player = "Bao"
    print("bạn chọn Bao")
    
if player == computer:
    print("Máy chọn: " + computer)
    print("người chơi Hòa!")
elif player == "Kéo":
    if computer == "Búa":
        print("Máy chọn: " + computer)
        print("người chơi Thua")
    else:
        print("Máy chọn: " + computer)
        print("người chơi Thắng")
elif player == "Búa":
    if computer == "Bao":
        print("Máy chọn: " + computer)
        print("người chơi Thua")
    else:
        print("Máy chọn: " + computer)
        print("người chơi Thắng")
elif player == "Bao":
        if computer == "Kéo":
            print("Máy chọn: " + computer)
            print("người chơi Thua")
        else:
            print("Máy chọn: " + computer)
            print("người chơi Thắng")
else:
    print("bạn nhập sai rồi ")
# Out:
# Mời lựa chọn(1 - búa, 2 - kéo, 3 - bao): 4
# bạn nhập sai rồi
